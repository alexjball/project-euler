# %%
import solver

# %%
for d in range(1, 10):
    # for k in range(-100, 100):
    for k in range(13):
        n = 9 * 10**k
        print(f"f({k}, {d}) =\t{solver.f(n, d) - n}")
# Out:
# f(0, 1) =	-8
# f(1, 1) =	-71
# f(2, 1) =	-620
# f(3, 1) =	-5300
# f(4, 1) =	-44000
# f(5, 1) =	-350000
# f(6, 1) =	-2600000
# f(7, 1) =	-17000000
# f(8, 1) =	-80000000
# f(9, 1) =	100000000
# f(10, 1) =	10000000000
# f(11, 1) =	190000000000
# f(12, 1) =	2800000000000
# f(0, 2) =	-8
# f(1, 2) =	-71
# f(2, 2) =	-620
# f(3, 2) =	-5300
# f(4, 2) =	-44000
# f(5, 2) =	-350000
# f(6, 2) =	-2600000
# f(7, 2) =	-17000000
# f(8, 2) =	-80000000
# f(9, 2) =	100000000
# f(10, 2) =	10000000000
# f(11, 2) =	190000000000
# f(12, 2) =	2800000000000
# f(0, 3) =	-8
# f(1, 3) =	-71
# f(2, 3) =	-620
# f(3, 3) =	-5300
# f(4, 3) =	-44000
# f(5, 3) =	-350000
# f(6, 3) =	-2600000
# f(7, 3) =	-17000000
# f(8, 3) =	-80000000
# f(9, 3) =	100000000
# f(10, 3) =	10000000000
# f(11, 3) =	190000000000
# f(12, 3) =	2800000000000
# f(0, 4) =	-8
# f(1, 4) =	-71
# f(2, 4) =	-620
# f(3, 4) =	-5300
# f(4, 4) =	-44000
# f(5, 4) =	-350000
# f(6, 4) =	-2600000
# f(7, 4) =	-17000000
# f(8, 4) =	-80000000
# ...

# %%
""
